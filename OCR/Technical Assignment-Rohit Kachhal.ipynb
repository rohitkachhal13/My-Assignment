# %% [markdown]
# ### 1. Importing Important Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pytesseract
import cv2
import re
import PIL

from pytesseract import Output
from pdf2image import convert_from_path
from PIL import Image

# %% [markdown]
# ### 2. Path Of Document

# %%
input_doc = r'E:/DATA TRAINED/Pinnacle Assignment/pinnacle_inv_3300004000.pdf'

# %% [markdown]
# ### 3. Convert PDF to Image And Store The Image

# %%
input_sample = convert_from_path(input_doc,350,poppler_path=r'C:/Users/Rohit Kachhal/poppler-0.68.0/bin')

i = 1
for j in input_sample:
    file_name = "Invoice_" + str(i) + ".jpg"
    j.save(file_name, "JPEG")
    i = i+1

# %% [markdown]
# ### 4. Read And Display The Image Using Open CV

# %%
jpg_image = cv2.imread("Invoice_1.jpg")

imgResize = cv2.resize(jpg_image,(900,650))
cv2.imshow('Resize image',imgResize)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 5. Applying Threshold To Make Image More Readable

# %%
_, result = cv2.threshold(jpg_image,120,255,cv2.THRESH_BINARY)

imgResize = cv2.resize(jpg_image,(900,650))
cv2.imshow('image',imgResize)
imgResize_1 = cv2.resize(result,(900,650))
cv2.imshow('result',imgResize_1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 6. Text From Image

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\Rohit Kachhal\AppData\Local\Tesseract-OCR\tesseract.exe'
custom_config = r'--oem 3 --psm 6'
img_text = pytesseract.image_to_string(jpg_image,config=custom_config)
print(img_text)
# Out:
# =aiir ATOMY LIVING IF COMPANY
# Bill To: Invoice,
# PINNACLE SOLUTIONS Invoice : 0380
# 21747 BERTRAM ROAD Date: 03/01/2020
# SAN JOSE 95120 P. Order #: 3300004000
# CA Terms: 30 days
# Attn = :Mr. Smith
# Description Amount
# Being supply of skilled labor, tools and equipments for grease trap desludging by means of
# vacuum desludging tanker and sewage effluent sampling (sewerage treatment service)
# for the month of Jan. 2020. USD 10,300.00
# (Our D/O No. 3046)
#
# Sub total - USD 10,300.00
# eee ecm ==) c ora Dt Mmmecomee w= C8210) 2 010
# —  — —RM_10,300.00
# USD TEN Thousand Three Hundred And 0 Cents.
#
# Authorized Signature
# =
# Mail Add.: 885, Central Parkway 78323 Texas
# Email: inquiry@if.com

# %% [markdown]
# ### 7. Boundary Of Each Character

# %%
h, w, _ = jpg_image.shape
boxes = pytesseract.image_to_boxes(jpg_image,config=custom_config) 
for b in boxes.splitlines():
    b = b.split(' ')
    imge = cv2.rectangle(jpg_image, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)
print(boxes)
# Out:
# = 486 3816 622 3827 0
# a 468 3741 731 3813 0
# i 669 3741 742 3827 0
# i 744 3746 766 3812 0
# r 780 3746 816 3812 0
# A 942 3757 1016 3860 0
# T 1025 3757 1095 3860 0
# O 1101 3754 1174 3862 0
# M 1188 3757 1263 3860 0
# Y 1272 3757 1337 3860 0
# L 1382 3757 1439 3860 0
# I 1449 3757 1459 3860 0
# V 1471 3757 1547 3860 0
# I 1560 3757 1570 3860 0
# N 1587 3757 1652 3860 0
# G 1665 3754 1730 3862 0
# I 1779 3757 1789 3860 0
# F 1807 3757 1856 3860 0
# C 1901 3754 2049 3862 0
# O 2034 3754 2096 3863 0
# M 2063 3757 2138 3860 0
# P 2152 3757 2219 3863 0
# A 2223 3757 2297 3860 0
# N 2312 3757 2377 3860 0
# Y 2387 3757 2452 3860 0
# B 368 3438 397 3476 0
# i 384 3438 406 3478 0
# l 405 3439 428 3478 0
# l 433 3439 442 3478 0
# T 457 3439 488 3476 0
# o 490 3439 515 3466 0
# : 520 3439 527 3466 0
# I 2322 3444 2342 3489 0
# n 2347 3446 2376 3476 0
# v 2378 3446 2408 3476 0
# o 2396 3444 2423 3490 0
# i 2411 3446 2438 3477 0
# c 2443 3446 2457 3490 0
# e 2460 3446 2511 3478 0
# , 2524 3444 2526 3449 0
# P 369 3333 394 3367 0
# I 398 3333 405 3367 0
# N 410 3333 436 3367 0
# N 442 3333 468 3367 0
# A 472 3333 502 3366 0
# C 503 3333 531 3367 0
# L 535 3333 558 3367 0
# E 562 3333 587 3367 0
# S 600 3332 626 3367 0
# O 629 3332 660 3367 0
# L 665 3333 688 3367 0
# U 691 3332 717 3367 0
# T 721 3333 747 3367 0
# I 750 3333 757 3367 0
# O 761 3332 792 3367 0
# N 797 3333 823 3367 0
# S 827 3332 853 3367 0
# I 1999 3333 2004 3366 0
# n 2010 3333 2030 3358 0
# v 2033 3334 2054 3358 0
# o 2048 3332 2066 3366 0
# i 2056 3333 2078 3358 0
# c 2082 3332 2110 3366 0
# e 2112 3332 2134 3358 0
# : 2146 3333 2152 3357 0
# 0 2306 3334 2326 3367 0
# 3 2330 3334 2350 3368 0
# 8 2355 3334 2375 3368 0
# 0 2379 3334 2399 3368 0
# 2 366 3282 388 3315 0
# 1 395 3281 407 3314 0
# 7 417 3281 438 3315 0
# 4 436 3281 457 3314 0
# 7 461 3281 482 3315 0
# B 495 3281 548 3315 0
# E 550 3281 579 3319 0
# R 566 3280 595 3319 0
# T 584 3281 609 3314 0
# R 610 3281 639 3319 0
# A 644 3281 672 3314 0
# M 674 3280 702 3314 0
# R 725 3281 754 3319 0
# O 758 3281 788 3315 0
# A 792 3281 820 3314 0
# D 822 3281 848 3315 0
# D 1999 3281 2026 3315 0
# a 2017 3266 2035 3319 0
# t 2028 3281 2049 3306 0
# e 2052 3281 2063 3314 0
# : 2065 3280 2098 3306 0
# 0 2306 3281 2326 3315 0
# 3 2330 3281 2351 3315 0
# / 2352 3282 2364 3315 0
# 0 2367 3281 2387 3315 0
# 1 2395 3281 2408 3314 0
# / 2414 3282 2427 3315 0
# 2 2427 3281 2449 3314 0
# 0 2453 3281 2473 3315 0
# 2 2476 3282 2498 3315 0
# 0 2502 3281 2522 3314 0
# S 366 3229 390 3265 0
# A 392 3228 420 3261 0
# N 425 3228 449 3262 0
# J 465 3228 483 3261 0
# O 488 3228 518 3262 0
# S 521 3229 545 3264 0
# E 547 3229 571 3262 0
# 9 587 3228 607 3262 0
# 5 613 3229 633 3262 0
# 1 640 3228 652 3261 0
# 2 659 3229 681 3262 0
# 0 686 3228 706 3262 0
# P 1999 3228 2023 3261 0
# . 2027 3228 2033 3233 0
# O 2052 3228 2082 3262 0
# r 2087 3229 2099 3254 0
# d 2100 3228 2121 3261 0
# e 2114 3227 2137 3262 0
# r 2125 3227 2163 3254 0
# # 2175 3229 2200 3262 0
# : 2204 3229 2209 3253 0
# 3 2302 3229 2322 3263 0
# 3 2326 3229 2346 3263 0
# 0 2351 3229 2371 3263 0
# 0 2376 3229 2396 3263 0
# 0 2401 3229 2421 3263 0
# 0 2426 3229 2446 3263 0
# 4 2447 3229 2468 3262 0
# 0 2472 3229 2492 3263 0
# 0 2497 3229 2517 3263 0
# 0 2522 3229 2542 3263 0
# C 366 3175 394 3209 0
# A 397 3175 425 3208 0
# T 1996 3175 2021 3208 0
# e 2022 3174 2044 3200 0
# r 2049 3176 2061 3201 0
# m 2064 3175 2096 3200 0
# s 2082 3161 2105 3213 0
# : 2100 3174 2129 3201 0
# 3 2309 3176 2329 3210 0
# 0 2334 3176 2354 3210 0
# d 2369 3176 2390 3209 0
# a 2394 3176 2415 3201 0
# y 2420 3166 2439 3201 0
# s 2442 3175 2461 3202 0
# A 365 3018 393 3051 0
# t 395 3018 418 3051 0
# t 421 3018 441 3044 0
# n 433 3018 441 3051 0
# = 500 3003 510 3057 0
# : 531 3017 536 3042 0
# M 551 3017 583 3051 0
# r 590 3018 602 3043 0
# . 607 3017 612 3021 0
# S 629 3017 653 3053 0
# m 657 3017 689 3042 0
# i 694 3017 699 3050 0
# t 702 3017 713 3050 0
# h 717 3017 738 3051 0
# D 367 2912 394 2945 0
# e 397 2912 421 2937 0
# s 411 2902 434 2945 0
# c 423 2903 445 2937 0
# r 448 2904 470 2937 0
# i 475 2904 499 2945 0
# p 506 2902 530 2937 0
# t 530 2904 545 2944 0
# i 545 2904 555 2945 0
# o 561 2904 586 2937 0
# n 586 2904 611 2937 0
# A 2305 2904 2332 2945 0
# m 2336 2904 2371 2937 0
# o 2375 2905 2399 2937 0
# u 2403 2904 2413 2937 0
# n 2413 2904 2453 2937 0
# t 2457 2904 2471 2944 0
# B 367 2784 392 2817 0
# e 395 2783 417 2809 0
# i 422 2784 426 2817 0
# n 432 2784 452 2810 0
# g 457 2774 477 2809 0
# s 493 2783 512 2809 0
# u 517 2784 537 2809 0
# p 535 2774 553 2818 0
# p 543 2775 564 2809 0
# l 569 2775 590 2809 0
# y 594 2774 623 2818 0
# o 638 2784 660 2809 0
# f 661 2785 675 2818 0
# s 691 2783 710 2810 0
# k 703 2783 721 2818 0
# i 714 2785 733 2818 0
# l 736 2784 749 2817 0
# l 752 2784 757 2818 0
# e 761 2783 783 2809 0
# d 785 2784 806 2817 0
# l 826 2784 831 2818 0
# a 835 2784 856 2809 0
# b 861 2784 882 2817 0
# o 886 2784 908 2809 0
# r 912 2785 924 2810 0
# , 928 2778 934 2789 0
# t 948 2784 984 2817 0
# o 976 2783 995 2817 0
# o 988 2784 1010 2809 0
# l 1013 2783 1042 2817 0
# s 1034 2783 1042 2817 0
# a 1057 2784 1078 2809 0
# n 1085 2784 1105 2810 0
# d 1110 2784 1131 2817 0
# e 1147 2783 1169 2809 0
# q 1172 2775 1193 2810 0
# u 1198 2784 1218 2809 0
# i 1224 2784 1228 2817 0
# p 1233 2775 1254 2809 0
# m 1259 2784 1291 2809 0
# e 1281 2775 1304 2817 0
# n 1294 2783 1316 2809 0
# t 1320 2784 1340 2810 0
# s 1343 2783 1376 2816 0
# f 1392 2784 1405 2818 0
# o 1405 2784 1427 2809 0
# r 1431 2785 1443 2810 0
# g 1459 2774 1479 2809 0
# r 1484 2785 1496 2810 0
# e 1498 2783 1520 2809 0
# a 1522 2784 1543 2809 0
# s 1548 2783 1567 2810 0
# e 1569 2783 1591 2809 0
# t 1606 2784 1617 2817 0
# r 1621 2785 1634 2810 0
# a 1634 2784 1655 2809 0
# p 1660 2775 1681 2809 0
# d 1697 2784 1718 2817 0
# e 1722 2783 1744 2809 0
# s 1748 2783 1767 2810 0
# l 1770 2784 1775 2817 0
# u 1778 2784 1798 2809 0
# d 1802 2784 1823 2817 0
# g 1827 2774 1847 2809 0
# i 1852 2784 1857 2817 0
# n 1863 2784 1883 2810 0
# g 1887 2774 1907 2809 0
# b 1924 2784 1945 2817 0
# y 1947 2774 1966 2809 0
# m 1983 2784 2015 2809 0
# e 2019 2783 2041 2809 0
# a 2043 2784 2064 2809 0
# n 2054 2783 2077 2810 0
# s 2069 2783 2113 2810 0
# o 2127 2784 2139 2818 0
# f 2127 2784 2165 2818 0
# v 365 2733 384 2757 0
# a 386 2732 409 2758 0
# c 413 2732 432 2757 0
# u 434 2732 456 2757 0
# u 460 2732 480 2757 0
# m 485 2732 519 2758 0
# d 536 2732 557 2765 0
# e 550 2722 573 2765 0
# s 562 2731 584 2757 0
# l 589 2731 616 2765 0
# u 621 2732 641 2757 0
# d 646 2732 667 2765 0
# g 662 2722 681 2765 0
# i 671 2722 701 2765 0
# n 706 2732 726 2757 0
# g 730 2722 751 2757 0
# t 766 2732 778 2764 0
# a 779 2732 800 2757 0
# n 805 2732 825 2757 0
# k 831 2732 850 2766 0
# e 852 2731 874 2757 0
# r 879 2733 891 2758 0
# a 905 2732 926 2757 0
# n 932 2732 952 2757 0
# d 957 2732 978 2765 0
# s 995 2731 1014 2757 0
# e 1016 2731 1038 2757 0
# w 1040 2732 1073 2757 0
# a 1073 2732 1094 2757 0
# g 1085 2722 1108 2757 0
# e 1098 2722 1144 2757 0
# e 1160 2731 1171 2767 0
# f 1160 2732 1182 2758 0
# f 1184 2732 1217 2767 0
# l 1211 2731 1230 2767 0
# u 1222 2732 1242 2756 0
# e 1246 2732 1268 2758 0
# n 1274 2732 1293 2757 0
# t 1296 2731 1307 2764 0
# s 1323 2731 1342 2758 0
# a 1345 2732 1366 2757 0
# m 1371 2732 1404 2757 0
# p 1396 2722 1419 2765 0
# l 1408 2723 1429 2757 0
# i 1433 2732 1448 2765 0
# n 1454 2732 1474 2757 0
# g 1478 2722 1499 2757 0
# ( 1516 2724 1549 2765 0
# s 1540 2722 1563 2765 0
# e 1551 2731 1573 2757 0
# w 1575 2732 1608 2757 0
# e 1609 2731 1631 2757 0
# r 1635 2733 1647 2758 0
# a 1649 2732 1670 2757 0
# g 1673 2722 1694 2757 0
# e 1697 2731 1719 2757 0
# t 1735 2732 1746 2765 0
# r 1749 2733 1761 2758 0
# e 1762 2732 1779 2758 0
# a 1784 2732 1807 2758 0
# t 1809 2732 1820 2765 0
# m 1823 2732 1857 2758 0
# e 1860 2731 1882 2757 0
# n 1873 2731 1891 2765 0
# t 1886 2732 1920 2765 0
# s 1936 2731 1955 2758 0
# e 1957 2731 1979 2757 0
# r 1983 2733 1995 2758 0
# v 1998 2733 2017 2758 0
# i 2020 2732 2024 2765 0
# c 2028 2731 2048 2758 0
# e 2050 2731 2072 2757 0
# ) 2075 2725 2085 2766 0
# f 375 2673 389 2706 0
# o 388 2672 412 2698 0
# r 416 2673 428 2698 0
# t 441 2672 453 2704 0
# h 456 2672 477 2706 0
# e 480 2671 502 2697 0
# m 520 2672 552 2697 0
# o 556 2672 578 2697 0
# n 574 2672 592 2706 0
# t 582 2672 616 2705 0
# h 620 2672 641 2706 0
# o 658 2672 680 2697 0
# f 682 2672 695 2706 0
# J 707 2672 725 2705 0
# a 730 2672 751 2697 0
# n 757 2672 777 2698 0
# . 782 2672 788 2677 0
# 2 806 2673 828 2706 0
# 0 832 2672 852 2706 0
# 2 854 2673 876 2706 0
# 0 869 2672 887 2706 0
# . 881 2672 911 2706 0
# U 2258 2672 2282 2707 0
# S 2286 2674 2310 2709 0
# D 2311 2673 2337 2707 0
# 1 2353 2673 2365 2706 0
# 0 2375 2673 2395 2707 0
# , 2401 2667 2406 2678 0
# 3 2411 2673 2431 2707 0
# 0 2436 2673 2456 2707 0
# 0 2461 2673 2481 2707 0
# . 2486 2673 2492 2678 0
# 0 2498 2673 2518 2707 0
# 0 2523 2673 2543 2707 0
# ( 366 2559 383 2598 0
# O 380 2565 412 2598 0
# u 414 2566 433 2587 0
# r 434 2567 452 2586 0
# D 465 2566 495 2597 0
# / 492 2566 513 2598 0
# O 511 2566 541 2598 0
# N 553 2566 584 2596 0
# o 573 2566 594 2596 0
# . 584 2566 611 2588 0
# 3 631 2566 651 2597 0
# 0 654 2566 674 2597 0
# 4 676 2566 695 2597 0
# 6 691 2556 707 2597 0
# ) 698 2556 730 2596 0
# S 1820 1244 1848 1278 0
# u 1838 1244 1861 1278 0
# b 1852 1244 1898 1277 0
# t 1912 1244 1918 1278 0
# o 1912 1244 1924 1276 0
# t 1926 1244 1948 1269 0
# a 1949 1244 1960 1277 0
# l 1962 1244 1993 1278 0
# - 2157 1258 2163 1284 0
# U 2244 1244 2268 1279 0
# S 2273 1245 2297 1281 0
# D 2299 1245 2325 1279 0
# 1 2340 1245 2352 1278 0
# 0 2360 1245 2380 1279 0
# , 2389 1239 2394 1251 0
# 3 2400 1245 2420 1279 0
# 0 2425 1245 2445 1279 0
# 0 2450 1245 2470 1279 0
# . 2477 1245 2482 1251 0
# 0 2488 1245 2508 1279 0
# 0 2513 1245 2533 1279 0
# e 369 1181 1465 1230 0
# e 369 1181 2569 1230 0
# e 1543 1181 1594 1230 0
# e 1604 1167 1627 1234 0
# c 1626 1167 1661 1234 0
# m 1660 1167 1750 1234 0
# = 1827 1167 1845 1234 0
# = 1844 1167 1862 1234 0
# ) 1861 1167 1890 1234 0
# c 1917 1167 1923 1234 0
# o 1933 1167 1951 1234 0
# r 1950 1167 1973 1234 0
# a 1972 1167 1990 1234 0
# D 2000 1167 2018 1234 0
# t 2017 1167 2057 1234 0
# M 2084 1167 2096 1234 0
# m 2095 1167 2119 1234 0
# m 2118 1167 2141 1234 0
# e 2140 1167 2158 1234 0
# c 2157 1167 2169 1234 0
# o 2168 1167 2174 1234 0
# m 2173 1167 2191 1234 0
# e 2190 1167 2202 1234 0
# e 2201 1167 2230 1234 0
# w 2252 1167 2269 1234 0
# = 2268 1167 2292 1234 0
# C 2330 1167 2359 1234 0
# 8 2358 1167 2387 1234 0
# 2 2386 1167 2409 1234 0
# 1 2408 1167 2420 1234 0
# 0 2419 1167 2437 1234 0
# ) 2436 1167 2448 1234 0
# 2 2453 1167 2465 1234 0
# 0 2481 1167 2498 1234 0
# 1 2497 1167 2515 1234 0
# 0 2514 1167 2571 1234 0
# — 366 1048 450 1111 0
# ~ 465 1048 524 1111 0
# — 523 1048 671 1111 0
# — 2216 1068 2249 1110 0
# R 2248 1068 2281 1110 0
# M 2280 1068 2312 1110 0
# _ 2311 1068 2328 1110 0
# 1 2327 1068 2349 1110 0
# 0 2348 1068 2375 1110 0
# , 2216 1068 2568 1110 0
# 3 2395 1068 2417 1110 0
# 0 2416 1068 2438 1110 0
# 0 2437 1068 2464 1110 0
# . 2464 1068 2485 1110 0
# 0 2485 1068 2506 1110 0
# 0 2506 1068 2527 1110 0
# U 366 957 390 992 0
# S 395 958 419 994 0
# D 421 958 447 992 0
# T 461 958 486 991 0
# E 487 959 511 992 0
# N 516 958 540 992 0
# T 557 958 583 992 0
# h 586 958 607 992 0
# o 610 958 632 983 0
# u 636 958 656 983 0
# s 660 957 679 984 0
# a 682 958 703 983 0
# n 708 958 728 983 0
# d 732 958 752 991 0
# T 768 958 793 991 0
# h 796 958 817 992 0
# r 821 959 833 984 0
# e 835 957 857 983 0
# e 859 957 881 983 0
# H 895 958 921 991 0
# u 926 958 946 983 0
# n 951 958 971 984 0
# d 975 958 995 991 0
# r 1001 959 1013 984 0
# e 1014 957 1036 983 0
# d 1038 958 1058 991 0
# A 1074 958 1102 991 0
# n 1107 958 1127 984 0
# d 1131 958 1151 991 0
# 0 1168 958 1189 992 0
# C 1202 958 1230 992 0
# e 1234 957 1256 983 0
# n 1246 957 1265 992 0
# t 1262 958 1282 983 0
# s 1286 958 1297 991 0
# . 1300 957 1330 983 0
# A 1920 700 1945 729 0
# u 1951 699 1960 720 0
# t 1961 699 1983 725 0
# h 1984 699 2005 731 0
# o 2007 699 2027 722 0
# r 2028 699 2039 721 0
# i 2040 699 2058 729 0
# z 2056 699 2074 721 0
# e 2075 699 2093 721 0
# d 2094 699 2118 732 0
# S 2126 699 2150 730 0
# i 2150 699 2161 728 0
# g 2159 689 2184 720 0
# n 2185 699 2206 721 0
# a 2207 699 2227 720 0
# t 2231 699 2241 725 0
# u 2244 699 2263 720 0
# r 2265 699 2273 720 0
# e 2276 699 2301 721 0
# = 382 563 2549 594 0
# M 888 506 916 540 0
# a 905 506 923 541 0
# i 919 507 936 533 0
# l 942 507 955 541 0
# A 969 507 994 540 0
# d 995 506 1014 540 0
# d 1016 506 1035 539 0
# . 1040 507 1046 512 0
# : 1051 507 1055 533 0
# 8 1067 507 1087 539 0
# 8 1089 507 1109 541 0
# 5 1110 507 1130 539 0
# , 1134 502 1138 513 0
# C 1151 507 1179 541 0
# e 1183 506 1205 532 0
# n 1210 507 1230 532 0
# t 1233 507 1244 540 0
# r 1247 508 1259 533 0
# a 1261 507 1282 532 0
# l 1287 507 1292 541 0
# P 1308 507 1332 540 0
# a 1335 507 1356 532 0
# r 1361 508 1373 533 0
# k 1376 507 1394 541 0
# w 1395 505 1425 530 0
# a 1427 507 1448 532 0
# y 1452 497 1472 532 0
# 7 1487 507 1508 541 0
# 8 1512 507 1532 541 0
# 3 1534 507 1554 541 0
# 2 1557 508 1579 541 0
# 3 1583 507 1603 541 0
# T 1629 507 1654 540 0
# e 1655 506 1677 532 0
# x 1680 507 1698 530 0
# a 1700 507 1721 532 0
# s 1726 506 1745 532 0
# E 932 456 954 490 0
# m 956 456 986 480 0
# a 973 456 991 490 0
# i 989 456 1007 479 0
# l 1010 456 1015 489 0
# : 1020 456 1035 489 0
# i 1048 456 1053 489 0
# n 1058 456 1078 481 0
# q 1083 447 1104 482 0
# u 1109 456 1129 481 0
# i 1134 456 1139 489 0
# r 1144 457 1156 482 0
# y 1157 446 1177 481 0
# @ 1181 446 1216 492 0
# i 1220 456 1225 489 0
# f 1228 456 1242 490 0
# . 1242 455 1271 482 0
# c 1265 446 1284 492 0
# o 1274 456 1296 481 0
# m 1300 456 1332 481 0

# %% [markdown]
# ### 8. Marking Boundary Of Each Character Into Image

# %%
imgResize = cv2.resize(jpg_image,(900,650))
cv2.imshow('Resize image',imgResize)
cv2.waitKey(0)
cv2.destroyAllWindows()

#plt.figure(figsize=(15,25))
#plt.imshow(imge)

# %% [markdown]
# ### 9. Fixed The Boundary Of Each Word

# %%
d = pytesseract.image_to_data(jpg_image,config=custom_config,output_type=Output.DICT)
print(d.keys())
# Out:
# dict_keys(['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num', 'left', 'top', 'width', 'height', 'conf', 'text'])

# %% [markdown]
# ### 10. Marking Boundary Of Each Word Into Image

# %%
n_boxes = len(d['text'])
for i in range(n_boxes):
    if int(float(d['conf'][i])) > 20:
        (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
        img = cv2.rectangle(jpg_image, (x, y), (x + w, y + h), (0, 255, 0), 2)
        img = cv2.putText(img,d['text'][i],(x,y+h+20),cv2.FONT_HERSHEY_SIMPLEX,0.7,(25,25,112),4,cv2.LINE_AA)

imgResize = cv2.resize(img,(900,650))
cv2.imshow('Resize image',imgResize)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 11. Based On Regular Expression Match Pattern From Image

# %%
new_img = cv2.imread("Invoice_1.jpg")
d = pytesseract.image_to_data(new_img, output_type=Output.DICT)
keys = list(d.keys())

date_pattern = '^(0[1-9]|1[0-2])/(0[1-9]|[12][0-9]|3[01])/(19|20)\d\d$'
invoice_pattern = '\d{4}$'
po_pattern = '\d{10}$'
term_pattern = '([0-9]|0[1-9]|[12][0-9]|3[01])\s\w+$'
pay_pattern = '\d{2},\d{3}.\d{2}'

n_boxes = len(d['text'])
for i in range(n_boxes):
    if int(float(d['conf'][i])) > 60:
        if re.match(date_pattern, d['text'][i]):
            (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
            img = cv2.rectangle(new_img, (x, y), (x + w, y + h), (0, 255, 0), 2)
    
    if int(float(d['conf'][i])) > 60:
        if re.match(invoice_pattern, d['text'][i]):
            (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
            img = cv2.rectangle(new_img, (x, y), (x + w, y + h), (0, 255, 0), 2)
            
    #if int(float(d['conf'][i])) > 60:
        #if re.match(po_pattern, d['text'][i]):
            #(x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
            #img = cv2.rectangle(new_img, (x, y), (x + w, y + h), (0, 255, 0), 2)   
            
    #if int(float(d['conf'][i])) > 35:
        #if re.match(term_pattern, d['text'][i]):
            #(x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
            #img = cv2.rectangle(new_img, (x, y), (x + w, y + h), (0, 255, 0), 2)
          
    if int(float(d['conf'][i])) > 35:
        if re.match(pay_pattern, d['text'][i]):
            (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
            img = cv2.rectangle(new_img, (x, y), (x + w, y + h), (0, 255, 0), 2)    
imgResize = cv2.resize(img,(900,650))
cv2.imshow('Resize image',imgResize)
cv2.waitKey(0)
cv2.destroyAllWindows()   
plt.figure(figsize=(15,25))
plt.imshow(img)
